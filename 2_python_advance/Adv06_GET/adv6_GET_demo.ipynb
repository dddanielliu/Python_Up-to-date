# %% [markdown]
# # 練習
#
# - 觀察 https://movies.yahoo.com.tw/chart.html 並撰寫爬蟲程式
# - 抓取台北當週票房排行榜
# - 使用 requests + BeautifulSoup 實作
# - 透過 pandas 輸出成 csv

# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = 'https://movies.yahoo.com.tw/chart.html'

# %%
# 200:存取正確
# 403:存取拒絕
# 404:網頁不存在
#Requests呼叫網頁用的套件/指令
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="501887343352051" property="fb:app_id"/>
# <meta content="Yahoo奇摩電影" property="og:site_name"/>
# <link href="/favicon.ico?v=2" rel="icon"/>
# <title>台北票房榜 - Yahoo奇摩電影</title>
# <meta content="台北票房榜 - Yahoo奇摩電影" name="twitter:title"/>
# <meta content="台北票房榜 - Yahoo奇摩電影" property="og:title"/>
# <link href="https://movies.yahoo.com.tw/chart.html" rel="canonical"/>
# <meta content="https://movies.yahoo.com.tw/chart.html" property="og:url"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="twitter:description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" property="og:description"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" property="og:image"/>
# <meta content="https://movies.yahoo.com.tw/build/images/ogImage.png" name="twitter:image:src"/>
# <meta content="電影, yahoo奇摩電影, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度" name="keywords"/>
# <link href="/build/css/app.css?id=7217e6ab0ebdeb31eb68669af6ea79f3&amp;r=1632993902" rel="stylesheet"/>
# <meta content="guce.yahoo.com.tw" name="oath:guce:consent-host"/>
# <!-- Consent Manager Tag : Script -->
# <script async="" src="https://consent.cmp.oath.com/cmp.js" type="text/javascript"></script>
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js" type="text/javascript"></script></head>
# <body id="">
# <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
# <span data-pt="minihome" data-spaceid="794026727" id="tracking-data"></span>
# <!--Website-->
# <div id="maincontainer">
# <header>
# <div id="y-header">
# <nav class="nav content">
# <ul>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']" href="https://tw.yahoo.com/"><span class="icon_home"></span>首頁</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']" href="https://tw.mail.yahoo.com/">信箱</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']" href="https://tw.news.yahoo.com/">新聞</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']" href="https://tw.stock.yahoo.com/">股市</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']" href="https://tw.news.yahoo.com/weather-forecast/">氣象</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']" href="https://tw.sports.yahoo.com/">運動</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']" href="https://tw.news.yahoo.com/entertainment">名人娛樂</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']" href="http://tw.mobile.yahoo.com/">App下載</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']" href="https://tw.buy.yahoo.com/">購物中心</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']" href="https://tw.mall.yahoo.com/">商城</a></li>
# <li><a class="gabtn" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']" href="https://tw.bid.yahoo.com/">拍賣</a></li>
# <li class="nav_more">
# <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
# <div class="dropdown_list">
# <dl>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']" href="https://tw.video.yahoo.com/">影音</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']" href="https://autos.yahoo.com.tw/">汽車機車</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']" href="https://movies.yahoo.com.tw/">電影</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']" href="https://tw.dictionary.yahoo.com/">字典</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']" href="https://games.yahoo.com.tw/">遊戲</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']" href="https://travel.yahoo.com.tw/">旅遊</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']" href="https://tw.money.yahoo.com/">理財</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']" href="https://house.yahoo.com.tw/">房地產</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']" href="https://style.yahoo.com.tw/">時尚美妝</a></dd>
# <dd><a class="gabtn" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']" href="https://tw.discount.yahoo.net/index.php?group=all">折扣城</a></dd>
# </dl>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div id="kv">
# <div class="content">
# <div class="_c" id="y_hous_serch">
# <div id="y_serch_l">
# <a class="gabtn" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']" href="https://movies.yahoo.com.tw/index.html" id="ylogo">
# <img alt="Yahoo Logo" src="/build/images/header_logo.png" srcset="/build/images/header_logo@2x.png 2x, /build/images/header_logo@3x.png 3x"/>
# </a>
# <form action="https://tw.search.yahoo.com/search" method="get" target="_blank">
# <input autocomplete="off" id="serchinput" name="p" placeholder="搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden"></div>
# <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">電影‧明星搜尋</button><!--20170531-->
# <button class="gabtn" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']" type="submit">網頁搜尋</button><!--20170531-->
# <input id="fr" name="fr" type="hidden" value="ush-movies"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
# <div class="content">
# <ul id="mainmenu">
# <li><a class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']" href="https://movies.yahoo.com.tw" target="">
# <span>首頁</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']" href="https://movies.yahoo.com.tw/movie_thisweek.html" target="">
# <span>本週新片</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']" href="https://movies.yahoo.com.tw/movie_intheaters.html" target="">
# <span>上映中</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']" href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="">
# <span>即將上映</span>
# </a></li>
# <li><a class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']" href="https://movies.yahoo.com.tw/trailer_index.html" target="">
# <span>預告片</span>
# </a></li>
# <li class="select"><a class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']" href="https://movies.yahoo.com.tw/chart.html" target="">
# <span>排行榜</span>
# </a></li>
# <li class="hassub">
# <a class="gabtn" data-ga="['選單','選單_情報站','頁首_選單']" href="https://movies.yahoo.com.tw/article_index.html" target="">
# <span>情報站</span></a>
# <div class="submenu">
# <dl class="submenu_inner">
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/movieheadline" target="">
#                               電影新聞</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/spotlight" target="">
#                               專題報導</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/moviereview" target="">
#                               影評</a></dt>
# </dl>
# </div>
# </li>
# <li><a class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']" href="https://movies.yahoo.com.tw/tv_index.html" target="">
# <span>電視時刻</span>
# </a></li>
# <li class="hassub">
# <a class="gabtn" data-ga="['選單','選單_追劇咖','頁首_選單']" href="https://movies.yahoo.com.tw/ott_index.html" target="">
# <span>追劇咖</span></a>
# <div class="submenu">
# <dl class="submenu_inner">
# <dt><a class="gabtn" data-ga="['選單','選單_追劇咖_線上戲劇','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/ottdrama" target="">
#                               線上戲劇</a></dt>
# <dt><a class="gabtn" data-ga="['選單','選單_追劇咖_線上電影','頁首_選單']" href="https://movies.yahoo.com.tw/tagged/ottmovie" target="">
#                               線上電影</a></dt>
# </dl>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <!--主內容-->
# <main>
# <!--top_ad-->
# <div class="maincontent ga_ranking">
# <div class="boxAD" id="boxMAST"></div>
# <div class="content _c" id="top_serch">
# <div data-topserch="0">
# <div class="tab_serch _c">
# <div class="tab_hot">
# <a class="gabtn" data-ga="['search box','search box_熱門1','娜歐蜜華茲']" href="https://movies.yahoo.com.tw/movieinfo_main/絕命通話-the-desperate-hour-12649" target="">娜歐蜜華茲</a>
# <a class="gabtn" data-ga="['search box','search box_熱門2','凝弒']" href="https://movies.yahoo.com.tw/movieinfo_main/凝弒-cracked-12626" target="">凝弒</a>
# <a class="gabtn" data-ga="['search box','search box_熱門3','華燈初上']" href="https://tw.news.yahoo.com/《華燈初上》第三部走向線索懶人包-四要點剖析大結局兇手現形關鍵！-091416961.html" target="">華燈初上</a>
# </div>
# <a class="btn_booking btn_toptxt gabtn" data-ga="['search box','search box_訂票客服中心','']" href="https://www.ezding.com.tw/page/faq/faq.html" target="_blank">訂票客服中心</a>
# <a class="btn_all btn_toptxt gabtn" data-ga="['search box','search box_戲院總覽','']" href="https://movies.yahoo.com.tw/theater_list.html">戲院總覽</a>
# </div>
# <span data-url="https://movies.yahoo.com.tw" id="mainURL"></span>
# <span data-type="0" id="searchType"></span>
# <div class="tab_serchbar">
# <div class="icon_serch"></div>
# <select id="movie_time" name="search_type">
# <option value="0">電影時刻</option>
# <option value="1">電視時刻</option>
# <option value="2">快速訂票</option>
# <option value="3">電影/明星搜尋</option>
# </select>
# <!--tab_serchbar  style0-->
# <div class="top_change" data-change="0" style="">
# <form action="https://movies.yahoo.com.tw/movietime_result.html" id="form_moviearea" method="get">
# <span>選擇<br/>片名</span>
# <select class="movie_name" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# <option data-name="東京教父：4K數位修復版" value="12806">東京教父：4K數位修復版</option>
# <option data-name="藍色恐懼：數位修復版" value="12805">藍色恐懼：數位修復版</option>
# <option data-name="極限逃殺" value="12783">極限逃殺</option>
# <option data-name="劫獄救援" value="12782">劫獄救援</option>
# <option data-name="奇怪的數學家" value="12757">奇怪的數學家</option>
# <option data-name="高山上的熱氣球" value="12756">高山上的熱氣球</option>
# <option data-name="少年吔" value="12687">少年吔</option>
# <option data-name="終極堡壘" value="12673">終極堡壘</option>
# <option data-name="全面掃蕩" value="12648">全面掃蕩</option>
# <option data-name="丟包大作戰" value="12623">丟包大作戰</option>
# <option data-name="獵殺戰場" value="12606">獵殺戰場</option>
# <option data-name="遊走塵市間" value="12566">遊走塵市間</option>
# <option data-name="今敏：造夢魔術師" value="12520">今敏：造夢魔術師</option>
# <option data-name="願未央" value="12420">願未央</option>
# <option data-name="魔法水果籃 -前奏曲-" value="12162">魔法水果籃 -前奏曲-</option>
# <option data-name="壞蛋聯盟" value="12033">壞蛋聯盟</option>
# <option data-name="咒" value="11477">咒</option>
# <option data-name="再見列寧！" value="12760">再見列寧！</option>
# <option data-name="絕命第19排" value="12672">絕命第19排</option>
# <option data-name="接棒家族" value="12671">接棒家族</option>
# <option data-name="茲山魚譜" value="12655">茲山魚譜</option>
# <option data-name="絕命通話" value="12649">絕命通話</option>
# <option data-name="貝爾法斯特" value="12647">貝爾法斯特</option>
# <option data-name="Fate / Stay night 無限劍製" value="12635">Fate / Stay night 無限劍製</option>
# <option data-name="凝弒" value="12626">凝弒</option>
# <option data-name="青春換日線" value="12432">青春換日線</option>
# <option data-name="該死的阿修羅" value="11636">該死的阿修羅</option>
# <option data-name="巴黎夢想家" value="12525">巴黎夢想家</option>
# <option data-name="生命理賠師" value="12454">生命理賠師</option>
# <option data-name="平行母親" value="12208">平行母親</option>
# <option data-name="蝙蝠俠" value="10904">蝙蝠俠</option>
# <option data-name="瑪雅蜜蜂大冒險：守護小金蛋" value="12605">瑪雅蜜蜂大冒險：守護小金蛋</option>
# <option data-name="密室譯戰" value="12453">密室譯戰</option>
# <option data-name="黑光行動" value="12444">黑光行動</option>
# <option data-name="時代革命" value="12424">時代革命</option>
# <option data-name="春光乍洩 4K修復" value="12128">春光乍洩 4K修復</option>
# <option data-name="劇場版 咒術迴戰 0" value="12385">劇場版 咒術迴戰 0</option>
# <option data-name="黑盒線索" value="12433">黑盒線索</option>
# <option data-name="世界上最爛的人" value="12405">世界上最爛的人</option>
# <option data-name="鬼電梯" value="12389">鬼電梯</option>
# <option data-name="電影版 昨日的美食" value="12388">電影版 昨日的美食</option>
# <option data-name="垃圾頭" value="12322">垃圾頭</option>
# <option data-name="愛別離苦" value="11487">愛別離苦</option>
# <option data-name="秘境探險" value="11588">秘境探險</option>
# <option data-name="王牌冤家" value="12534">王牌冤家</option>
# <option data-name="在車上" value="12274">在車上</option>
# <option data-name="讓我聽見愛的歌聲" value="12197">讓我聽見愛的歌聲</option>
# <option data-name="幸福知音" value="11869">幸福知音</option>
# <option data-name="尼羅河謀殺案" value="10897">尼羅河謀殺案</option>
# <option data-name="波米叔叔的前世今生" value="12443">波米叔叔的前世今生</option>
# <option data-name="記憶" value="12442">記憶</option>
# <option data-name="我吃了那男孩一整年的早餐" value="12202">我吃了那男孩一整年的早餐</option>
# <option data-name="素還真" value="11545">素還真</option>
# <option data-name="歡樂好聲音2" value="11413">歡樂好聲音2</option>
# <option data-name="妖果小學-水果奶奶的大秘密" value="12194">妖果小學-水果奶奶的大秘密</option>
# <option data-name="我的神秘狼朋友" value="12138">我的神秘狼朋友</option>
# <option data-name="屁屁偵探：舒芙蕾島的秘密" value="11993">屁屁偵探：舒芙蕾島的秘密</option>
# <option data-name="西城故事" value="11519">西城故事</option>
# <option data-name="再說一次我願意" value="11888">再說一次我願意</option>
# <option data-name="G風暴" value="12041">G風暴</option>
# <option data-name="致命最前線" value="11951">致命最前線</option>
# <option data-name="驚聲尖叫" value="11561">驚聲尖叫</option>
# <option data-name="鄰危不亂" value="11641">鄰危不亂</option>
# <option data-name="Gucci：豪門謀殺案" value="11444">Gucci：豪門謀殺案</option>
# <option data-name="魔鬼剋星：未來世" value="10415">魔鬼剋星：未來世</option>
# <option data-name="阿達一族2" value="11512">阿達一族2</option>
# <option data-name="一杯熱奶茶的等待" value="11601">一杯熱奶茶的等待</option>
# <option data-name="駭客任務：復活" value="11744">駭客任務：復活</option>
# <option data-name="愛上費加洛" value="11670">愛上費加洛</option>
# <option data-name="夢想裁縫師" value="11599">夢想裁縫師</option>
# <option data-name="蜘蛛人：無家日" value="11479">蜘蛛人：無家日</option>
# <option data-name="法蘭西特派週報" value="11633">法蘭西特派週報</option>
# <option data-name="美國女孩" value="11600">美國女孩</option>
# <option data-name="魔法滿屋" value="11736">魔法滿屋</option>
# <option data-name="偶然與想像" value="11597">偶然與想像</option>
# <option data-name="沒說出口的殺人告白" value="11564">沒說出口的殺人告白</option>
# <option data-name="月老" value="11563">月老</option>
# <option data-name="梅艷芳" value="11419">梅艷芳</option>
# <option data-name="史賓賽" value="11542">史賓賽</option>
# <option data-name="永恆族" value="11472">永恆族</option>
# <option data-name="異類崛起" value="11500">異類崛起</option>
# <option data-name="不丹是教室" value="10789">不丹是教室</option>
# <option data-name="一首搖滾上月球" value="4887">一首搖滾上月球</option>
# <option data-name="錢不夠用2" value="3026">錢不夠用2</option>
# </select>
# <span>選擇<br/>地區</span>
# <select class="movie_area" id="sbox_aid" name="area_id">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style1-->
# <div class="top_change" data-change="1" style="display:none;">
# <form action="https://movies.yahoo.com.tw/tv_channels.html" id="form_catechannel" method="get" style="display:inline;">
# <span>選擇<br/>分類</span>
# <select class="movie_theater" id="sbox_cid" name="tv_category_id">
# <option value="">請選擇分類</option>
# <option data-name="西片" value="1">西片</option>
# <option data-name="國片" value="2">國片</option>
# <option data-name="戲劇" value="3">戲劇</option>
# <option data-name="體育" value="4">體育</option>
# <option data-name="綜合" value="5">綜合</option>
# <option data-name="知性" value="6">知性</option>
# <option data-name="日本" value="7">日本</option>
# <option data-name="音樂" value="8">音樂</option>
# <option data-name="卡通" value="9">卡通</option>
# <option data-name="新聞" value="10">新聞</option>
# <option data-name="財經" value="11">財經</option>
# <option data-name="宗教" value="12">宗教</option>
# </select>
# <span>選擇<br/>頻道</span>
# <select class="movie_name" id="sbox_chid" name="channel">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
# </form>
# <form action="https://movies.yahoo.com.tw/tvtime_result.html" id="form_channelname" method="get" style="display:inline;">
# <input autocomplete="off" class="tvserch" id="sbox_cname" name="tv_channel_name" onblur="this.placeholder='電視節目查詢'" onfocus="this.placeholder=''" onkeypress="chlSearchForm(event);" placeholder="電視節目查詢" type="text"/>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style2-->
# <div class="top_change" data-change="2" style="display:none;">
# <form action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&amp;campaign_code=yahoopc" id="form_movieticket" method="get">
# <span>選擇<br/>戲院</span>
# <select class="movie_theater" id="sbox_tid" name="cinemaId">
# <option value="">請選擇戲院</option>
# <option value="40288eb0050f542401050f554e7e0674">台北信義威秀影城</option>
# <option value="46efa950eafa11e38b12987bdb90dba4">台北樂聲影城</option>
# <option value="b020ba50fbc811e58858f2128151146f">梅花數位影城</option>
# <option value="f644412efbb811e58858f2128151146f">台北真善美劇院</option>
# <option value="cf2b5aa8132f11e6b767a1b123456789">台北獅子林新光影城</option>
# <option value="40288eb0050f542401050f55532606b5">喜滿客絕色影城</option>
# <option value="40288eb0050f31210ada0f55676b1bbc">台北美麗華大直影城</option>
# <option value="4c163aba9c5311e494ae8b4ddf78b93a">台北新民生戲院</option>
# <option value="5f60dacd-45b3-102d-8d74-e400529c">台北京站威秀影城</option>
# <option value="e9c365f27f4e11e494ae8b4ddf78b93a">台北in89豪華數位影城</option>
# <option value="40288eb0050f542401050f5681782dc5">喜樂時代影城南港店</option>
# <option value="40288eb0050f542401050f5550201811">哈拉影城</option>
# <option value="470e99e70b5611eaa91e06ba2bcebcfa">MUVIE CINEMAS台北松仁威秀</option>
# <option value="c93fa3fb52a34755b123838886cc8599">中和環球威秀影城</option>
# <option value="73544d843cd311e69bb83d0f96c001c2">林口MITSUI OUTLET PARK威秀影城</option>
# <option value="c072c5c43fc011e9a245782bcb259cad">喜樂時代影城永和店</option>
# <option value="737ece862a0111e18e86000bdb90dba4">板橋大遠百威秀影城</option>
# <option value="c256b670b10811e8959e782bcb259cad">桃園統領威秀影城</option>
# <option value="e6ffb324b55b4e1ab6d074be7e6abf09">台北天母新光影城</option>
# <option value="43e1c5fc8abc4cb7ae03d061f892d7ab">桃園青埔新光影城</option>
# <option value="e5cc98b5ff424b599c063cf80a20e86b">喜樂時代影城桃園A19店</option>
# <option value="5d4b59f567ac11e7a6b1061be09fe071">桃園in89統領影城</option>
# <option value="40288eb0050f542401050f5573651ca2">新竹大遠百威秀影城</option>
# <option value="4f9fbbac7a2d11e18e86000bdb90dba4">新竹巨城威秀影城</option>
# <option value="883ddebefe9e11e49e5e8d16c6a1d23a">頭份尚順威秀影城</option>
# <option value="7ff29bea908122e9060e893bcb360cad">台中豐原in89豪華影城</option>
# <option value="40288eb0050f542401050f5576601cdc">台中Tiger City威秀影城</option>
# <option value="84599c0a220d11e18e86000bdb90dba4">台中大遠百威秀影城</option>
# <option value="40288eb0050f542401050f557dfc1d65">台南大遠百威秀影城</option>
# <option value="370b0003943222e8a7b2172be10fe182">台南FOCUS威秀影城</option>
# <option value="5d4b59f597ac11e7a6b1091be09fe001">台南真善美劇院</option>
# <option value="c3ab0cdc8cad11e494ae8b4ddf78b93a">台南南紡威秀影城</option>
# <option value="a6f9c512bec5463183d3d7eaec37fb42">台南西門新光影城</option>
# <option value="44f76448bf2511e59a5d4b53bcb866d6">高雄in89駁二電影院</option>
# <option value="40288eb0050f542401050f5582141dac">高雄大遠百威秀影城</option>
# <option value="40288eb0050f542401050f5581582dc5">喜滿客夢時代影城</option>
# <option value="2c28121ae2c711e292f7000bdb90dba4">中影屏東影城</option>
# <option value="6ff18bea897011e8959e782bcb259cad">澎湖in89豪華影城</option>
# </select>
# <span>選擇<br/>片名</span>
# <select class="movie_name" id="sbox_tmid" name="movieId">
# </select>
# <span>選擇<br/>日期</span>
# <select class="movie_day" name="showDate">
# </select>
# <span>選擇<br/>場次</span>
# <select class="movie_screenings" name="session">
# </select>
# <span>選擇<br/>數量</span>
# <select class="movie_amount" name="ticketQuantity">
# </select>
# <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']" data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
# </form>
# </div>
# <!--tab_serchbar  style3-->
# <div class="top_change" data-change="3" style="display:none;">
# <form action="https://movies.yahoo.com.tw/moviesearch_result.html" id="form_starsearch" method="get">
# <input autocomplete="off" class="starserch" id="starserch" name="keyword" onblur="this.placeholder='電影/ 明星搜尋'" onfocus="this.placeholder=''" placeholder="電影 / 明星搜尋" type="text"/>
# <div class="inputex" style="visibility:hidden">
# </div>
# <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']" data-input="['input','starserch','']">查詢</div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="content _c" id="container">
# <div id="content_r">
# <!--AD 300X250-->
# <!-- if $exist diff with 0 will removed from module section -->
# <div class="top_ad_300_250 r_box" data-ad="LREC" data-ad-hashtag="" id="boxLREC">
# </div>
# <!--AD 300X100-->
# <div class="ad_300_250 r_box" data-ad="NP1" id="boxNP1">
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             電影排行榜
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="tabbox_btn_r">
# <li class="select" data-id="list1">台北票房榜</li>
# <li data-id="list2">全美票房榜</li>
# <li data-id="list3">預告片榜</li>
# </ul>
# <div class="ranking_inner_r">
# <div class="tab-content">
# <div class="tab-pane" id="list1">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904"><img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/January2022/0Y14kp9wm5gx1gJNRBr6-1382x2048.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904">
#                   蝙蝠俠</a>
# <span class="text_truncate_4 text_truncate_dot"><p>《蝙蝠俠》將聚焦於一個年輕版本的布魯斯韋恩，並從中檢視他在面罩之下的靈魂。羅伯派汀森將在新版《蝙蝠俠》中飾演這位DC超級英雄，電影是由《猩球崛起：終極決戰》導演麥特李維斯（Matt Reeves）所執導。</p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904">
# <li class="select">
# <div class="num">1</div>
# <span>蝙蝠俠</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','劇場版 咒術迴戰 0']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8A%87%E5%A0%B4%E7%89%88-%E5%92%92%E8%A1%93%E8%BF%B4%E6%88%B0-0-jujutsu-kaisen-0-the-movie-12385">
# <li class="">
# <div class="num">2</div>
# <span>劇場版 咒術迴戰 0</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','時代革命']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%99%82%E4%BB%A3%E9%9D%A9%E5%91%BD-revolution-of-our-times-12424">
# <li class="">
# <div class="num">3</div>
# <span>時代革命</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','秘境探險']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%A7%98%E5%A2%83%E6%8E%A2%E9%9A%AA-uncharted-11588">
# <li class="">
# <div class="num">4</div>
# <span>秘境探險</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','該死的阿修羅']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%B2%E6%AD%BB%E7%9A%84%E9%98%BF%E4%BF%AE%E7%BE%85-goddamned-asura-11636">
# <li class="">
# <div class="num">5</div>
# <span>該死的阿修羅</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','青春換日線']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9D%92%E6%98%A5%E6%8F%9B%E6%97%A5%E7%B7%9A-reborn-12432">
# <li class="">
# <div class="num">6</div>
# <span>青春換日線</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','世界上最爛的人']" href="https://movies.yahoo.com.tw/movieinfo_main/%E4%B8%96%E7%95%8C%E4%B8%8A%E6%9C%80%E7%88%9B%E7%9A%84%E4%BA%BA-the-worst-person-in-the-world-12405">
# <li class="">
# <div class="num">7</div>
# <span>世界上最爛的人</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','絕命通話']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%91%BD%E9%80%9A%E8%A9%B1-the-desperate-hour-12649">
# <li class="">
# <div class="num">8</div>
# <span>絕命通話</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','我吃了那男孩一整年的早餐']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91%E5%90%83%E4%BA%86%E9%82%A3%E7%94%B7%E5%AD%A9%E4%B8%80%E6%95%B4%E5%B9%B4%E7%9A%84%E6%97%A9%E9%A4%90-my-best-friends-breakfast-12202">
# <li class="">
# <div class="num">9</div>
# <span>我吃了那男孩一整年的早餐</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_台北票房榜','在車上']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%9C%A8%E8%BB%8A%E4%B8%8A-drive-my-car-12274">
# <li class="">
# <div class="num">10</div>
# <span>在車上</span>
# </li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2022-03-12~2022-03-13</div>
# </div>
# <div class="tab-pane" id="list2">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904">
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/January2022/0Y14kp9wm5gx1gJNRBr6-1382x2048.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904">
#                   蝙蝠俠</a>
# <span class="text_truncate_4 text_truncate_dot"><p>《蝙蝠俠》將聚焦於一個年輕版本的布魯斯韋恩，並從中檢視他在面罩之下的靈魂。羅伯派汀森將在新版《蝙蝠俠》中飾演這位DC超級英雄，電影是由《猩球崛起：終極決戰》導演麥特李維斯（Matt Reeves）所執導。</p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','蝙蝠俠']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904">
# <li class="select">
# <div class="num">1</div>
# <span>蝙蝠俠</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','秘境探險']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%A7%98%E5%A2%83%E6%8E%A2%E9%9A%AA-uncharted-11588">
# <li class="">
# <div class="num">2</div>
# <span>秘境探險</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">3</div>
# <span>BTS Permission to Dance on Stage - Seoul: Live Viewing</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','逍遙上路']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%8D%E9%81%99%E4%B8%8A%E8%B7%AF-dog-12130">
# <li class="">
# <div class="num">4</div>
# <span>逍遙上路</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','蜘蛛人：無家日']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9C%98%E8%9B%9B%E4%BA%BA-%E7%84%A1%E5%AE%B6%E6%97%A5-spider-man-no-way-home-11479">
# <li class="">
# <div class="num">5</div>
# <span>蜘蛛人：無家日</span>
# </li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','尼羅河謀殺案']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%B0%BC%E7%BE%85%E6%B2%B3%E8%AC%80%E6%AE%BA%E6%A1%88-death-on-the-nile-10897">
# <li class="">
# <div class="num">6</div>
# <span>尼羅河謀殺案</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">7</div>
# <span>Radhe Shyam</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','歡樂好聲音2']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%AD%A1%E6%A8%82%E5%A5%BD%E8%81%B2%E9%9F%B32-sing-2-11413">
# <li class="">
# <div class="num">8</div>
# <span>歡樂好聲音2</span>
# </li>
# </a>
# <li class="unclick">
# <div class="num">9</div>
# <span>Jackass Forever</span>
# </li>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_全美票房榜','驚聲尖叫']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%A9%9A%E8%81%B2%E5%B0%96%E5%8F%AB-scream-11561">
# <li class="">
# <div class="num">10</div>
# <span>驚聲尖叫</span>
# </li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2022-03-11~2022-03-13</div>
# </div>
# <div class="tab-pane" id="list3">
# <div class="ranking_top_info_r _c">
# <div class="ranking_top_info_img_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','咒']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%92%92-incantation-11477"><img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/February2022/vjyrHV1QwVaAya1lA1Jg-500x714.jpg"/></a>
# </div>
# <div class="ranking_top_info_inner_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','咒']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%92%92-incantation-11477">
#                     咒</a>
# <span class="text_truncate_4 text_truncate_dot"><p>不信邪的若男和男友等人組成影像團隊，四處到鬧鬼場景拍片破除謠言，六年前，他們大膽闖入邪教儀式中的禁地，觸怒了沈睡的邪靈，詛咒在世間蔓延。男友當場猝死，其他成員接二連三的發瘋、離奇死於非命，唯一生還的是因腳傷而未進入的若男。</p>
# <p> </p>
# <p>六年後，她女兒竟畫出當年儀式的符號，不僅時常對著無人角落說話，更出現奇怪的皮膚病，牙齒變得畸形、發黑掉落，都是當年的邪靈作祟！若男為了拯救女兒不惜一切代價，決定冒著生命危險重回禁地，找出詛咒的秘密。</p>
# <p> </p>
# <p>【關於電影】</p>
# <p> </p>
# <p>《咒》是由故事主角若男以其第一人稱陳述、拍攝、剪輯而成的自白書信，影片中有若男六年前所經歷的恐怖事實，可能藏在危險⋯如果害怕無法承受的，現在可以離開。願意留下來的，請在觀看過程中遵守每一個指示，以防詛咒纏身。</p>
# <p> </p>
# <p>本片使用大量的互動橋段，包含記住符號、默念咒語『火佛修一 心薩嘸哞』，讓觀眾身歷其境、體驗一場儀式的感受，並跟著主角若男一同化解女兒所遭受的詛咒。</p>
# <p> </p></span>
# </div>
# </div>
# <ul class="ranking_list_r">
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','咒']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%92%92-incantation-11477">
# <li class="select">
# <div class="num">1</div>
# <span>咒</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','頭七']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%A0%AD%E4%B8%83-12430">
# <li class="">
# <div class="num">2</div>
# <span>頭七</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','該死的阿修羅']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%B2%E6%AD%BB%E7%9A%84%E9%98%BF%E4%BF%AE%E7%BE%85-goddamned-asura-11636">
# <li class="">
# <div class="num">3</div>
# <span>該死的阿修羅</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','少年吔']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%B0%91%E5%B9%B4%E5%90%94-untouchable-12687">
# <li class="">
# <div class="num">4</div>
# <span>少年吔</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','絕命第19排']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%91%BD%E7%AC%AC19%E6%8E%92-row-19-12672">
# <li class="">
# <div class="num">5</div>
# <span>絕命第19排</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','壞蛋聯盟']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E8%9B%8B%E8%81%AF%E7%9B%9F-the-bad-guys-12033">
# <li class="">
# <div class="num">6</div>
# <span>壞蛋聯盟</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','凝弒']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%87%9D%E5%BC%92-cracked-12626">
# <li class="">
# <div class="num">7</div>
# <span>凝弒</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','魔比斯']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%AD%94%E6%AF%94%E6%96%AF-morbius-10462">
# <li class="">
# <div class="num">8</div>
# <span>魔比斯</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','絕命通話']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%91%BD%E9%80%9A%E8%A9%B1-the-desperate-hour-12649">
# <li class="">
# <div class="num">9</div>
# <span>絕命通話</span></li>
# </a>
# <a class="gabtn" data-ga="['電影排行榜','電影排行榜_預告片榜','音速小子2']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9F%B3%E9%80%9F%E5%B0%8F%E5%AD%902-sonic-the-hedgehog-2-11999">
# <li class="">
# <div class="num">10</div>
# <span>音速小子2</span></li>
# </a>
# </ul>
# <div class="rankin_time_r">統計時間 : 2022-03-18</div>
# </div>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
# <div class="plus"></div>看更多
#         </a>
# </div>
# <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
# <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
# <div class="plus"></div>看更多
#         </a>
# </div>
# </div>
# </div>
# </div>
# <!--AD 300X156-->
# <div class="native-ad-right">
# </div>
# <!--AD 300X250-->
# <div class="ad_300_250 r_box" data-ad="LREC3" id="boxLREC3">
# <div id="tgtLREC3"></div>
# </div>
# <!--FB-->
# <div class="fb r_box">
# </div>
# <!--你最近瀏覽的電影-->
# <div class="r_box _c">
# <div class="title">
# <span>
#             你最近瀏覽的電影
#         </span>
# </div>
# <div class="r_box_inner">
# <ul class="recently_viewed">
# </ul>
# </div>
# </div>
# <div></div>
# </div>
# <div id="content_l">
# <div id="content_l">
# <!--電影資訊-->
# <div class="l_box">
# <div class="movie_tab">
# <ul class="movie_tab_list split">
# <li class="select">
# <a class="gabtn" data-ga="['排行榜','排行榜_台北票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html">台北票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_全美票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=us">全美票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_週冠軍票房列表tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=week">週冠軍票房列表</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_年度票房榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=year">年度票房榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_預告片榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=trailer">預告片榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_網友期待榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=exp_30">網友期待榜</a>
# </li>
# <li>
# <a class="gabtn" data-ga="['排行榜','排行榜_網友滿意榜tab','']" href="https://movies.yahoo.com.tw/chart.html?cate=rating">網友滿意榜</a>
# </li>
# </ul>
# </div>
# <div class="rank_list_infobox">
# <div class="sharebox">
# <a class="fbicon fb_share_send" href="#"><img alt="" src="/build/images/icon_share_fb.png"/></a>
# </div>
# </div>
# <div class="rank_list table rankstyle1">
# <div class="tr top">
# <div class="td">本週</div>
# <div class="td updown"></div>
# <div class="td">上週</div>
# <div class="td">片名</div>
# <div class="td">上映日期</div>
# <div class="td">預告片</div>
# <div class="td">網友滿意度</div>
# </div>
# <div class="tr">
# <div class="td">1</div>
# <div class="td up"></div>
# <div class="td">1</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%9D%99%E8%9D%A0%E4%BF%A0-the-batman-10904"> <dl class="rank_list_box">
# <dt>
# <img alt="" src="https://movies.yahoo.com.tw/x/r/w420/i/o/production/movies/January2022/0Y14kp9wm5gx1gJNRBr6-1382x2048.jpg"/>
# </dt>
# <dd>
# <h2>蝙蝠俠</h2>
# <h3>The Batman</h3>
# <span class="jq_text_overflow_80 jq_text_overflow_link">
#                                                             《蝙蝠俠》將聚焦於一個年輕版本的布魯斯韋恩，並從中檢視他在面罩之下的靈魂。羅伯派汀森將在新版《蝙蝠俠》中飾演這位DC超級英雄，電影是由《猩球崛起：終極決戰》導演麥特李維斯（Matt Reeves）所執導。
#                                                         </span>
# </dd>
# </dl>
# </a> </div>
# <div class="td">2022-03-03</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%9D%99%E8%9D%A0%E4%BF%A0-%E5%B9%95%E5%BE%8C%E8%8A%B1%E7%B5%AE-081941895.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4" data-run="0">4</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">2</div>
# <div class="td up"></div>
# <div class="td">2</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%8A%87%E5%A0%B4%E7%89%88-%E5%92%92%E8%A1%93%E8%BF%B4%E6%88%B0-0-jujutsu-kaisen-0-the-movie-12385"> <div class="rank_txt">劇場版 咒術迴戰 0</div>
# </a> </div>
# <div class="td">2022-02-24</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%8A%87%E5%A0%B4%E7%89%88-%E5%92%92%E8%A1%93%E8%BF%B4%E6%88%B0-0-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-155846363.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.6" data-run="0">4.6</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">3</div>
# <div class="td up"></div>
# <div class="td">3</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%99%82%E4%BB%A3%E9%9D%A9%E5%91%BD-revolution-of-our-times-12424"> <div class="rank_txt">時代革命</div>
# </a> </div>
# <div class="td">2022-02-25</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%99%82%E4%BB%A3%E9%9D%A9%E5%91%BD-%E5%B0%8E%E6%BC%94%E5%91%A8%E5%86%A0%E5%A8%81%E5%AE%A3%E5%82%B3%E5%BD%B1%E5%83%8F-082144344.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.5" data-run="0">4.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">4</div>
# <div class="td up"></div>
# <div class="td">4</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%A7%98%E5%A2%83%E6%8E%A2%E9%9A%AA-uncharted-11588"> <div class="rank_txt">秘境探險</div>
# </a> </div>
# <div class="td">2022-02-17</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E7%A7%98%E5%A2%83%E6%8E%A2%E9%9A%AA-%E6%B9%AF%E5%A7%86%E9%9C%8D%E8%98%AD%E5%BE%B7-%E9%A6%AC%E5%85%8B%E8%8F%AF%E6%9F%8F%E6%A0%BC%E7%8D%A8%E5%AE%B6%E5%B0%88%E8%A8%AA-040100741.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">5</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%B2%E6%AD%BB%E7%9A%84%E9%98%BF%E4%BF%AE%E7%BE%85-goddamned-asura-11636"> <div class="rank_txt">該死的阿修羅</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%A9%B2%E6%AD%BB%E7%9A%84%E9%98%BF%E4%BF%AE%E7%BE%85-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-090334518.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.2" data-run="0">4.2</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">6</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%9D%92%E6%98%A5%E6%8F%9B%E6%97%A5%E7%B7%9A-reborn-12432"> <div class="rank_txt">青春換日線</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E9%9D%92%E6%98%A5%E6%8F%9B%E6%97%A5%E7%B7%9A-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-133651717.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">7</div>
# <div class="td down"></div>
# <div class="td">5</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E4%B8%96%E7%95%8C%E4%B8%8A%E6%9C%80%E7%88%9B%E7%9A%84%E4%BA%BA-the-worst-person-in-the-world-12405"> <div class="rank_txt">世界上最爛的人</div>
# </a> </div>
# <div class="td">2022-02-18</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E4%B8%96%E7%95%8C%E4%B8%8A%E6%9C%80%E7%88%9B%E7%9A%84%E4%BA%BA-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-153345638.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">8</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%91%BD%E9%80%9A%E8%A9%B1-the-desperate-hour-12649"> <div class="rank_txt">絕命通話</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E7%B5%95%E5%91%BD%E9%80%9A%E8%A9%B1-%E5%AE%98%E6%96%B9%E9%A0%90%E5%91%8A-064537689.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="2.4" data-run="0">2.4</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">9</div>
# <div class="td down"></div>
# <div class="td">7</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%88%91%E5%90%83%E4%BA%86%E9%82%A3%E7%94%B7%E5%AD%A9%E4%B8%80%E6%95%B4%E5%B9%B4%E7%9A%84%E6%97%A9%E9%A4%90-my-best-friends-breakfast-12202"> <div class="rank_txt">我吃了那男孩一整年的早餐</div>
# </a> </div>
# <div class="td">2022-01-28</div>
# <div class="td icon_notice">
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.1" data-run="0">4.1</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">10</div>
# <div class="td down"></div>
# <div class="td">8</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%9C%A8%E8%BB%8A%E4%B8%8A-drive-my-car-12274"> <div class="rank_txt">在車上</div>
# </a> </div>
# <div class="td">2022-02-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%9C%A8%E8%BB%8A%E4%B8%8A-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-144236734.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.1" data-run="0">4.1</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">11</div>
# <div class="td down"></div>
# <div class="td">6</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%B0%BC%E7%BE%85%E6%B2%B3%E8%AC%80%E6%AE%BA%E6%A1%88-death-on-the-nile-10897"> <div class="rank_txt">尼羅河謀殺案</div>
# </a> </div>
# <div class="td">2022-02-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%B0%BC%E7%BE%85%E6%B2%B3%E8%AC%80%E6%AE%BA%E6%A1%88-%E5%A5%A2%E8%8F%AF%E6%9C%8D%E8%A3%9D%E7%AF%87-134359372.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.8" data-run="0">3.8</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">12</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%B2%9D%E7%88%BE%E6%B3%95%E6%96%AF%E7%89%B9-belfast-12647"> <div class="rank_txt">貝爾法斯特</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%B2%9D%E7%88%BE%E6%B3%95%E6%96%AF%E7%89%B9-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-041331112.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">13</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%87%9D%E5%BC%92-cracked-12626"> <div class="rank_txt">凝弒</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%87%9D%E5%BC%92-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-064623323.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.5" data-run="0">3.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">14</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%8E%A5%E6%A3%92%E5%AE%B6%E6%97%8F-and-so-the-baton-is-passed-12671"> <div class="rank_txt">接棒家族</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%8E%A5%E6%A3%92%E5%AE%B6%E6%97%8F-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-150341068.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.3" data-run="0">4.3</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">15</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%B5%95%E5%91%BD%E7%AC%AC19%E6%8E%92-row-19-12672"> <div class="rank_txt">絕命第19排</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E7%B5%95%E5%91%BD%E7%AC%AC19%E6%8E%92-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-032157626.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="2.7" data-run="0">2.7</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">16</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <div class="rank_txt">PHANTOM: THE MUSICAL FILM</div>
# </div>
# <div class="td">未定</div>
# <div class="td icon_notice">
# </div>
# <div class="td starwithnum">
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">17</div>
# <div class="td down"></div>
# <div class="td">9</div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E6%98%A5%E5%85%89%E4%B9%8D%E6%B4%A9-4K%E4%BF%AE%E5%BE%A9-happy-together-12128"> <div class="rank_txt">春光乍洩 4K數位修復版</div>
# </a> </div>
# <div class="td">2022-02-25</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E6%98%A5%E5%85%89%E4%B9%8D%E6%B4%A9-4k%E4%BF%AE%E5%BE%A9-%E5%BC%B5%E9%9C%87%E5%95%8F%E5%80%99%E5%BD%B1%E7%89%87-085956471.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.9" data-run="0">3.9</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">18</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%86%8D%E8%A6%8B%E5%88%97%E5%AF%A7-good-bye-lenin-12760"> <div class="rank_txt">再見列寧！《數位修復版》</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%86%8D%E8%A6%8B%E5%88%97%E5%AF%A7-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-164113096.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="3.5" data-run="0">3.5</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">19</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A3%9E%E8%9B%8B%E8%81%AF%E7%9B%9F-the-bad-guys-12033"> <div class="rank_txt">壞蛋聯盟</div>
# </a> </div>
# <div class="td">2022-03-18</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E5%A3%9E%E8%9B%8B%E8%81%AF%E7%9B%9F-%E4%B8%AD%E6%96%87%E9%85%8D%E9%9F%B3%E7%AF%87-033133562.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="0" data-run="0">0</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# <div class="tr">
# <div class="td">20</div>
# <div class="td new"></div>
# <div class="td"></div>
# <div class="td">
# <a href="https://movies.yahoo.com.tw/movieinfo_main/%E8%8C%B2%E5%B1%B1%E9%AD%9A%E8%AD%9C-the-book-of-fish-12655"> <div class="rank_txt">茲山魚譜</div>
# </a> </div>
# <div class="td">2022-03-11</div>
# <div class="td icon_notice">
# <a href="https://movies.yahoo.com.tw/video/%E8%8C%B2%E5%B1%B1%E9%AD%9A%E8%AD%9C-%E6%AD%A3%E5%BC%8F%E9%A0%90%E5%91%8A-165017723.html">預告片</a>
# </div>
# <div class="td starwithnum">
# <h6 class="count" data-num="4.2" data-run="0">4.2</h6>
# <div class="starbox starnumbox">
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# <div class="star">
# <div class="starovr" style="width: 15px;"></div>
# </div>
# </div>
# </div>
# <!--20170531 ▲-->
# </div>
# </div>
# <div class="rank_list_bottombtn">
# <ul>
# <li class="select"><a href="https://movies.yahoo.com.tw/chart.html">台北票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=us">全美票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=week">週冠軍票房列表</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=year">年度票房榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">預告片榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=exp_30">網友期待榜</a></li>
# <li><a href="https://movies.yahoo.com.tw/chart.html?cate=rating">網友滿意榜</a></li>
# </ul>
# <div class="rank_time">統計時間：2022-03-12~2022-03-13</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="clearfix" id="footer" style="display: block;">
# <div id="loadbox">
# <a class="gabtn" data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank">服務中心</a> | <a class="gabtn" data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm" target="_blank">隱私權(更新)</a> | <a class="gabtn" data-ga="['其他連結','其他連結_建議','頁尾_其他連結']" href="https://yahoo.uservoice.com/forums/600523" target="_blank">建議</a> | <a class="gabtn" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']" href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/" target="_blank">關於我們的廣告</a>
#   | <a class="gabtn" data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank">服務條款(更新)</a>
#   | <a href="" target="_blank">
# </a>
#   由Yahoo奇摩電影 提供
# </div> </footer>
# </div>
# <!-- Javascript -->
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId            : 501887343352051,
#             autoLogAppEvents : true,
#             xfbml            : true,
#             version          : 'v2.9'
#         });
#         FB.AppEvents.logPageView();
#     };
#
#     (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#
#     function fbShareSend() {
#         var shareSendAll = document.querySelectorAll('.fb_share_send');
#         for(var i = 0; i < shareSendAll.length; i++) {
#             shareSendAll[i].onclick = function() {
#                 FB.ui({
#                     method: 'share_open_graph',
#                     action_type: 'og.likes',
#                     action_properties: JSON.stringify({
#                         object: this.getAttribute('data-href') ? this.getAttribute('data-href') : 'https://movies.yahoo.com.tw/chart.html',
#                     })
#                 }, function(response){});
#             }
#         }
#     }
#
#     fbShareSend();
# </script>
# <script src="https://s.yimg.com/ss/rapid3.js"></script>
# <script src="https://s.yimg.com/ss/rapidworker-1.2.js"></script>
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   (function(d) {
#     var script = d.createElement("script");
#     script.async = true;
#     script.src = "https://s.yimg.com/dy/ads/native.js";
#     d.body.appendChild(script);
#   })(document);
# </script>
# <script src="/build/js/app.js?id=bc4e7eb7fecc1f7610e693286b8de26d&amp;r=1632993902" type="text/javascript"></script>
# <noscript><img alt="" height="1" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=7241469&amp;c7=https%3A%2F%2Fmovies.yahoo.com.tw%2Fchart.html&amp;c5=794026727&amp;cv=2.0&amp;cj=1" width="1"/></noscript>
# <script>
# </script>
# <script type="application/javascript">
#   (function (w, d, t, r, u) {
#     w[u] = w[u] || []
#     w[u].push({
#       'projectId': '10000',
#       'properties': {
#         'pixelId': '428726',
#         'qstrings': {'country': 'tw', 'property': 'movie', 'tag': ''}
#       }
#     })
#     var s = d.createElement(t)
#     s.src = r
#     s.async = true
#     s.onload = s.onreadystatechange = function () {
#       var y, rs = this.readyState, c = w[u]
#       if (rs && rs != 'complete' && rs != 'loaded') {return}
#       try {
#         y = YAHOO.ywa.I13N.fireBeacon
#         w[u] = []
#         w[u].push = function (p) {y([p])}
#         y(c)
#       } catch (e) {}
#     }
#     var scr = d.getElementsByTagName(t)[0], par = scr.parentNode
#     par.insertBefore(s, scr)
#   })(window, document, 'script', 'https://s.yimg.com/wi/ytc.js', 'dotq')
# </script>
# </body>
# </html>

# %%
column_name = soup.find('div',class_='tr top').text.split('\n')
column_name
# Out:
# ['', '本週', '', '上週', '片名', '上映日期', '預告片', '網友滿意度', '']

# %%
column_name = [i for i in column_name if i!='']
column_name
# Out:
# ['本週', '上週', '片名', '上映日期', '預告片', '網友滿意度']

# %%
df = pd.DataFrame(columns=column_name)
df
# Out:
# Empty DataFrame
# Columns: [本週, 上週, 片名, 上映日期, 預告片, 網友滿意度]
# Index: []

# %%
table = soup.find('div',class_='l_box')
len(table.find_all('div',class_='tr'))
# Out:
# 21

# %%
for rank in range(1,len(table.find_all('div',class_='tr'))):
    this_week = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[0].text
    last_week = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[2].text
    if rank == 1:
        name = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[3].h2.text
    else:
        name = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[3].find('div',class_='rank_txt').text
    date = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[4].text
    if table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[5].a != None:
        link = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[5].a['href']
    else:
        link = ''
    if table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[6].h6!=None:
        rating = table.find_all('div',class_='tr')[rank].find_all('div',class_='td')[6].h6.text
    else:
        rating =''
    df = df.append({'本週':this_week,'上週':last_week,'片名':name,'上映日期':date,'預告片':link,
              '網友滿意度':rating},ignore_index=True)

# %%
df
# Out:
#     本週 上週                         片名        上映日期  \
# 0    1  1                        蝙蝠俠  2022-03-03
# 1    2  2                 劇場版 咒術迴戰 0  2022-02-24
# 2    3  3                       時代革命  2022-02-25
# 3    4  4                       秘境探險  2022-02-17
# 4    5                        該死的阿修羅  2022-03-11
# 5    6                         青春換日線  2022-03-11
# 6    7  5                    世界上最爛的人  2022-02-18
# 7    8                          絕命通話  2022-03-11
# 8    9  7               我吃了那男孩一整年的早餐  2022-01-28
# 9   10  8                        在車上  2022-02-11
# 10  11  6                     尼羅河謀殺案  2022-02-11
# 11  12                         貝爾法斯特  2022-03-11
# 12  13                            凝弒  2022-03-11
# 13  14                          接棒家族  2022-03-11
# 14  15                        絕命第19排  2022-03-11
# 15  16     PHANTOM: THE MUSICAL FILM          未定
# 16  17  9               春光乍洩 4K數位修復版  2022-02-25
# 17  18                  再見列寧！《數位修復版》  2022-03-11
# 18  19                          壞蛋聯盟  2022-03-18
# 19  20                          茲山魚譜  2022-03-11
#
#                                                   預告片 網友滿意度
# 0   https://movies.yahoo.com.tw/video/%E8%9D%99%E8...     4
# 1   https://movies.yahoo.com.tw/video/%E5%8A%87%E5...   4.6
# 2   https://movies.yahoo.com.tw/video/%E6%99%82%E4...   4.5
# 3   https://movies.yahoo.com.tw/video/%E7%A7%98%E5...   3.9
# 4   https://movies.yahoo.com.tw/video/%E8%A9%B2%E6...   4.2
# 5   https://movies.yahoo.com.tw/video/%E9%9D%92%E6...   3.9
# 6   https://movies.yahoo.com.tw/video/%E4%B8%96%E7...   3.9
# 7   https://movies.yahoo.com.tw/video/%E7%B5%95%E5...   2.4
# 8                                                       4.1
# 9   https://movies.yahoo.com.tw/video/%E5%9C%A8%E8...   4.1
# 10  https://movies.yahoo.com.tw/video/%E5%B0%BC%E7...   3.8
# 11  https://movies.yahoo.com.tw/video/%E8%B2%9D%E7...   3.9
# 12  https://movies.yahoo.com.tw/video/%E5%87%9D%E5...   3.5
# 13  https://movies.yahoo.com.tw/video/%E6%8E%A5%E6...   4.3
# 14  https://movies.yahoo.com.tw/video/%E7%B5%95%E5...   2.7
# 15
# 16  https://movies.yahoo.com.tw/video/%E6%98%A5%E5...   3.9
# 17  https://movies.yahoo.com.tw/video/%E5%86%8D%E8...   3.5
# 18  https://movies.yahoo.com.tw/video/%E5%A3%9E%E8...     0
# 19  https://movies.yahoo.com.tw/video/%E8%8C%B2%E5...   4.2

# %%
df.to_csv('movie_2022_0318.csv',index=False)
