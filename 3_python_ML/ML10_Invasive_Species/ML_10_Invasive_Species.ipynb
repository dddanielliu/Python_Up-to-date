# %% [markdown]
# ## kaggle 外來物種CNN專題（專題2）
#
# ### 評分標準：(1-Kaggle名次百分比)*100 再開根號乘以十（四捨五入）
# e.x. Kaggle排名100/512 >> (1-(100/512)) * 100 ** (1/2) * 10 >>89.7
#
# #### 資料基本說明：
# <li>總資料大小:3.62GB</li>
# <li>訓練集：2295張大小為1154×866的彩色照片</li>
# <li>測試集：1531張大小為1154×866的彩色照片</li>
# <li>預測目標：是否為外來物種（是為1、否為0)</li>
#
#
# #### 注意事項
# <li>需上傳ipynb檔以及kaggle的分數截圖</li>
# <li>不得使用別人寫好的程式碼</li>

# %% [markdown]
# #### 第0步：下載資料 (https://www.kaggle.com/c/invasive-species-monitoring/) 或是來找我拿隨身碟

# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       1 import pandas as pd
# ----> 2 import cv2
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'cv2'

# %%
label = pd.read_csv('invasive_species/train_labels.csv')
label.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 label = pd.read_csv('invasive_species/train_labels.csv')
#       2 label.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
label  = label.invasive.values
label.shape
# Out:
# (2295,)

# %%
i = 1
img = cv2.imread('invasive_species/train/'+str(i)+'.jpg')
plt.imshow(img)

# %% [markdown]
# #### 第1步：資料處理、模型製作、訓練
#
# 注意事項提醒：
# - 留意參數量，避免跑不動的問題
# - Transfer Learning可能有用但效果會有限
# - 若圖片太大處理不動，可以考慮降畫質（參考方法： https://medium.com/@manivannan_data/resize-image-using-opencv-python-d2cdbbc480f0 ）
# - 是否為外來物種的照片差異其實很大，先看過一些照片可以協助你決定kernel size或其他模型的細節

# %% [markdown]
# #### 第2步：載入測試集、資料處理、預測

# %%
test_df = pd.read_csv('titanic/test.csv')
##資料處理

# pred = model.predict(test_df)

# %% [markdown]
# #### 最後一步：上傳檔案

# %%
submission = pd.read_csv('invasive_species/sample_submission.csv')
# submission.invasive=pred
# submission.head()

# %%
submission.to_csv('invasive_species/submission.csv',index=False)
